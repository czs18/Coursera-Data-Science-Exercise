# %%
# @hidden_cell

if (Sys.getenv("RUNTIME_ENV_LOCATION_TYPE") == "external") {
    endpoint_a7e26fa75c03487badd7fa4d1ff77f4d = "s3-api.us-geo.objectstorage.softlayer.net"
} else {
    endpoint_a7e26fa75c03487badd7fa4d1ff77f4d = "s3-api.us-geo.objectstorage.service.networklayer.com"
}

# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

library("aws.s3")
obj <- get_object(
    object = "house_price.csv",
    bucket = "mentoring1-donotdelete-pr-4hpsnxujnqmon5",
    key = "dbe89d7a6657489bb21dc15d8eeb0f8c",
    secret = "187ae643e6658fe13041a383de49b9d4c46fe55689ad77fb",
    check_region = FALSE,
    base_url = endpoint_a7e26fa75c03487badd7fa4d1ff77f4d)

df_data_1 <- read.csv(text = rawToChar(obj))
head(df_data_1)
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape LandContour
# 1 1  60         RL       65           8450   Pave   NA    Reg      Lvl
# 2 2  20         RL       80           9600   Pave   NA    Reg      Lvl
# 3 3  60         RL       68          11250   Pave   NA    IR1      Lvl
# 4 4  70         RL       60           9550   Pave   NA    IR1      Lvl
# 5 5  60         RL       84          14260   Pave   NA    IR1      Lvl
# 6 6  50         RL       85          14115   Pave   NA    IR1      Lvl
#   Utilities ⋯ PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold SaleType
# 1 AllPub    ⋯ 0        NA     NA    NA            0      2     2008   WD
# 2 AllPub    ⋯ 0        NA     NA    NA            0      5     2007   WD
# 3 AllPub    ⋯ 0        NA     NA    NA            0      9     2008   WD
# 4 AllPub    ⋯ 0        NA     NA    NA            0      2     2006   WD
# 5 AllPub    ⋯ 0        NA     NA    NA            0     12     2008   WD
# ...

# %%
library(ggplot2)

# %%
#Plot without grouping based on Garage Type
ggplot(df_data_1, aes(x = GarageArea, y = SalePrice)) +
    geom_point()
# Out:
# plot without title

# %%
#Plot without grouping based on Garage Type
ggplot(df_data_1, aes(x = GarageArea, y = SalePrice)) +
    geom_point(aes(color = factor(GarageCond)))
# Out:
# plot without title

# %%
#Find unique value of column in R
unique(df_data_1$GarageCond)
# Out:
# [1] TA   Fa   <NA> Gd   Po   Ex
# Levels: Ex Fa Gd Po TA
